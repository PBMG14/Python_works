# %% [markdown]
# <a href="https://colab.research.google.com/github/PBMG14/Python_works/blob/main/Work1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = int(input())
y = int(input())
print(x*y-(x**3-y**3)/(x**2+2*x*y+y**2))
# Out:
# 1
# 3
# 4.625

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from math import log, sqrt
x = int(input())
print(x**3*log(x)+log(4*sqrt(x) + 5))
# Out:
# 3
# 32.14143740944106

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from math import sqrt
a = int(input())
b = int(input())
c = int(input())
if a+b>c and a+c>b and b+c>a:
  p = (a+b+c)/2
  s = sqrt(p*(p-a)*(p-b)*(p-c))
  print(2*s/a)
  print(2*s/b)
  print(2*s/c)
else:
  print("Triangle doesn't exist")
# Out:
# 3
# 4
# 5
# 4.0
# 3.0
# 2.4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = int(input())
print(a//10+(a%10))
print(a//10*(a%10))
# Out:
# 00
# 0
# 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x1 = int(input())
y1 = int(input())
x2 = int(input())
y2 = int(input())
if abs(x1-x2)<=1 and abs(y1-y2)<=1:
  print('He can')
else:
  print('He can not')
# Out:
# 3
# 3
# 4
# 5
# He can not

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = int(input())
if(x >= -7):
  print(-x**2)
else:
  print(2**(-x)/(x**2-9))
# Out:
# 1
# -1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = int(input())
y = int(input())
if(x < y):
  temp = x
  x = y
  y = temp
print(x)
print(y)
# Out:
# 1
# 1
# 1
# 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from mpmath import cot
w = int(input())
if w == 0:
  w = 1
elif(cot(w) < 0.5):
  w = w * -1
print(w)
# Out:
# 180
# 180

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = int(input())
if(x**2 == ((x%10)**3+(x//10%10)**3 + (x//100)**3)):
  print('YES')
else:
  print('no')
# Out:
# 027
# no

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = int(input())
b = int(input())
c = int(input())
if(a+b>c and b+c>a and a+c>b):
  if(a*a+b*b==c*c or b*b+c*c==a*a or a*a+c*c==b*b):
    print("Right triangle")
  elif(a*a<b*b+c*c and b*b<c*c+a*c and c*c<a*a+b*b):
    print("Acute-triangle")
  else:
    print("obtus triangle")
  if(a == b and b == c):
    print("3 sides equal")
  elif(a == b or b == c or c == a):
    print("2 sides equal")
  else:
    print("every side different")
else:
  print("triangle doesn't exist")
# Out:
# 3
# 3
# 3
# Acute-triangle
# 3 sides equal

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = int(input())
a = int(input())
z = int(input())
x_copy = x
task1 = 0
task2 = 0
task3 = 0
while(x_copy):
  if(x_copy%10 == a): task1+=1
  if(x_copy%10 % z == 0): task2+=1
  if(x_copy%10>a):task3+=x_copy%10
  x_copy = x_copy//10
print(task1)
print(task2)
print(task3)
# Out:
# 12345
# 3
# 2
# 1
# 2
# 9

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = int(input())
p = 1
if(n <= 0):
  print("n/a")
else:
  for i in range (1,2*n,2):
    p*=i/(i+1)
  print(p)
# Out:
# 3
# 0.3125

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = int(input())
sum = 0
for i in range(0, n+1, 1):
  sum = sum + (2*i+i*i)/(2**i)
print(sum)
# Out:
# 9
# 9.716796875

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = int(input())
check = 0
mas = []*n
for i in range (0, n, 1):
  mas.append(float(input()))
for i in range (1, n-1, 1):
  if not((mas[i]<mas[i-1] and mas[i]<mas[i+1]) or (mas[i]>mas[i-1] and mas[i]>mas[i+1])):
    check = i
    break
print(check)
# Out:
# 3
# 2
# 1
# 2
# 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def prostoe(num):
  for i in range(2, num-1, 1):
    if(num%i == 0):
      return 0
  return 1
n = int(input())
if(n%2 != 0):
  print("The number is not even")
else:
  for i in range(1, n-1, 1):
    if(prostoe(n-i)):
      print(n-1 i)
# Out:
#   File "<ipython-input-5-43ba4f7b0bec>", line 1
#     def prostoe(num)
#                     ^
# SyntaxError: expected ':'
